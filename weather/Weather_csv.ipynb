# %%
import pandas as pd

weatherDF = pd.read_csv("weather_data.csv", encoding="cp949")
weatherDF = weatherDF[["지점명", "일시", "기온(°C)"]]
weatherDF
# Out:
#       지점명                일시  기온(°C)
# 0      서울  2020-01-01 00:00    -6.5
# 1      서울  2020-01-01 01:00    -5.9
# 2      서울  2020-01-01 02:00    -5.7
# 3      서울  2020-01-01 03:00    -5.6
# 4      서울  2020-01-01 04:00    -5.4
# ...    ..               ...     ...
# 17557  부산  2020-12-31 19:00     0.6
# 17558  부산  2020-12-31 20:00     0.1
# 17559  부산  2020-12-31 21:00    -0.2
# 17560  부산  2020-12-31 22:00    -0.7
# 17561  부산  2020-12-31 23:00    -0.7
#
# [17562 rows x 3 columns]

# %%
is_busan = weatherDF["지점명"] == "부산"
busan = weatherDF[is_busan]

temp = []
for date in busan["일시"]:
    temp.append(date.split(" ")[0])
temp_busan = []
unique_temp = set(temp) #set 자료형으로 형변환
for date in unique_temp:
    if temp.count(date) != 24:
        temp_busan.append(date)

empty_date = []
data_date = []
for date in busan["일시"]:
    for temp_date in temp_busan:
        if temp_date in date:
            empty_date.append(date.split(" ")[0])
            data_date.append(date)

empty_date = set(empty_date)
print(empty_date)
print(data_date)

full_date = []
for date in empty_date:
    for h in range(24):
        full_date.append(date + f" {str(h).zfill(2)}:00")

print(full_date)

full_empty_date_busan = []
for date in full_date:
    if date not in data_date:
        full_empty_date_busan.append(date)

print(full_empty_date_busan)
# Out:
# {'2020-08-26'}
# ['2020-08-26 00:00', '2020-08-26 01:00', '2020-08-26 02:00', '2020-08-26 03:00', '2020-08-26 05:00', '2020-08-26 07:00', '2020-08-26 08:00', '2020-08-26 09:00', '2020-08-26 10:00', '2020-08-26 11:00', '2020-08-26 12:00', '2020-08-26 13:00', '2020-08-26 16:00', '2020-08-26 17:00', '2020-08-26 18:00', '2020-08-26 19:00', '2020-08-26 20:00', '2020-08-26 22:00', '2020-08-26 23:00']
# ['2020-08-26 00:00', '2020-08-26 01:00', '2020-08-26 02:00', '2020-08-26 03:00', '2020-08-26 04:00', '2020-08-26 05:00', '2020-08-26 06:00', '2020-08-26 07:00', '2020-08-26 08:00', '2020-08-26 09:00', '2020-08-26 10:00', '2020-08-26 11:00', '2020-08-26 12:00', '2020-08-26 13:00', '2020-08-26 14:00', '2020-08-26 15:00', '2020-08-26 16:00', '2020-08-26 17:00', '2020-08-26 18:00', '2020-08-26 19:00', '2020-08-26 20:00', '2020-08-26 21:00', '2020-08-26 22:00', '2020-08-26 23:00']
# ['2020-08-26 04:00', '2020-08-26 06:00', '2020-08-26 14:00', '2020-08-26 15:00', '2020-08-26 21:00']

# %%
is_seoul = weatherDF["지점명"] == "서울"
seoul = weatherDF[is_seoul]

temp = []
for date in seoul["일시"]:
    temp.append(date.split(" ")[0])
temp_seoul = []
unique_temp = set(temp) #set 자료형으로 형변환
for date in unique_temp:
    if temp.count(date) != 24:
        temp_seoul.append(date)

empty_date = []
data_date = []
for date in seoul["일시"]:
    for temp_date in temp_seoul:
        if temp_date in date:
            empty_date.append(date.split(" ")[0])
            data_date.append(date)

empty_date = set(empty_date)
print(empty_date)
print(data_date)

full_date = []
for date in empty_date:
    for h in range(24):
        full_date.append(date + f" {str(h).zfill(2)}:00")

print(full_date)

full_empty_date_seoul = []
for date in full_date:
    if date not in data_date:
        full_empty_date_seoul.append(date)

print(full_empty_date_seoul)
# Out:
# {'2020-08-26'}
# ['2020-08-26 00:00', '2020-08-26 01:00', '2020-08-26 02:00', '2020-08-26 03:00', '2020-08-26 04:00', '2020-08-26 05:00', '2020-08-26 06:00', '2020-08-26 07:00', '2020-08-26 08:00', '2020-08-26 09:00', '2020-08-26 10:00', '2020-08-26 11:00', '2020-08-26 12:00', '2020-08-26 14:00', '2020-08-26 15:00', '2020-08-26 16:00', '2020-08-26 17:00', '2020-08-26 18:00', '2020-08-26 19:00', '2020-08-26 20:00', '2020-08-26 21:00', '2020-08-26 22:00', '2020-08-26 23:00']
# ['2020-08-26 00:00', '2020-08-26 01:00', '2020-08-26 02:00', '2020-08-26 03:00', '2020-08-26 04:00', '2020-08-26 05:00', '2020-08-26 06:00', '2020-08-26 07:00', '2020-08-26 08:00', '2020-08-26 09:00', '2020-08-26 10:00', '2020-08-26 11:00', '2020-08-26 12:00', '2020-08-26 13:00', '2020-08-26 14:00', '2020-08-26 15:00', '2020-08-26 16:00', '2020-08-26 17:00', '2020-08-26 18:00', '2020-08-26 19:00', '2020-08-26 20:00', '2020-08-26 21:00', '2020-08-26 22:00', '2020-08-26 23:00']
# ['2020-08-26 13:00']

# %%
full_empty_date = list(set(full_empty_date_seoul + full_empty_date_busan))

for date in full_empty_date:
    seoul = seoul[seoul["일시"] != date]
    busan = busan[busan["일시"] != date]

seoul
busan

time = []
for i in range(24):
    time.append(str(i).zfill(2) + ":00")

import numpy as np

zeros = np.zeros((24, 2))
df = pd.DataFrame(zeros, index=time, columns=["seoul", "busan"])
df
# Out:
#        seoul  busan
# 00:00    0.0    0.0
# 01:00    0.0    0.0
# 02:00    0.0    0.0
# 03:00    0.0    0.0
# 04:00    0.0    0.0
# 05:00    0.0    0.0
# 06:00    0.0    0.0
# 07:00    0.0    0.0
# 08:00    0.0    0.0
# 09:00    0.0    0.0
# 10:00    0.0    0.0
# 11:00    0.0    0.0
# 12:00    0.0    0.0
# 13:00    0.0    0.0
# 14:00    0.0    0.0
# 15:00    0.0    0.0
# 16:00    0.0    0.0
# 17:00    0.0    0.0
# 18:00    0.0    0.0
# 19:00    0.0    0.0
# 20:00    0.0    0.0
# 21:00    0.0    0.0
# 22:00    0.0    0.0
# 23:00    0.0    0.0

# %%
seoul
# Out:
#      지점명                일시  기온(°C)
# 0     서울  2020-01-01 00:00    -6.5
# 1     서울  2020-01-01 01:00    -5.9
# 2     서울  2020-01-01 02:00    -5.7
# 3     서울  2020-01-01 03:00    -5.6
# 4     서울  2020-01-01 04:00    -5.4
# ...   ..               ...     ...
# 8778  서울  2020-12-31 19:00    -7.1
# 8779  서울  2020-12-31 20:00    -7.1
# 8780  서울  2020-12-31 21:00    -7.2
# 8781  서울  2020-12-31 22:00    -7.4
# 8782  서울  2020-12-31 23:00    -7.6
#
# [8778 rows x 3 columns]

# %%
busan
# Out:
#       지점명                일시  기온(°C)
# 8783   부산  2020-01-01 00:00    -2.5
# 8784   부산  2020-01-01 01:00    -2.9
# 8785   부산  2020-01-01 02:00    -3.1
# 8786   부산  2020-01-01 03:00    -2.8
# 8787   부산  2020-01-01 04:00    -3.1
# ...    ..               ...     ...
# 17557  부산  2020-12-31 19:00     0.6
# 17558  부산  2020-12-31 20:00     0.1
# 17559  부산  2020-12-31 21:00    -0.2
# 17560  부산  2020-12-31 22:00    -0.7
# 17561  부산  2020-12-31 23:00    -0.7
#
# [8778 rows x 3 columns]

# %%
max_index = []

# print(seoul.iloc[0:24, 2].idxmax())

# 서울에서 각 시간마다의 기온을 리스트에 담고 그 리스트중에 가장 큰 값의 인덱스를 리스트에 담아야함
print(seoul[seoul["일시"]])

print(seoul.iloc[24:24+24, 2].idxmax())

for i in range(0, len(seoul), 24):
    max_index.append(seoul.iloc[i:i+24, 2].idxmax())

for i in max_index:
    df.loc[seoul.loc[i][1].split(" ")[1]]["seoul"] += 1

max_index = []
for i in range(0, len(busan), 24):
    max_index.append(busan.iloc[i:i+24, 2].idxmax())

for i in max_index:
    df.loc[busan.loc[i][1].split(" ")[1]]["busan"] += 1
df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\aws\python\basic\weather\Weather_csv.ipynb 셀 7 line 6
#       <a href='vscode-notebook-cell:/c%3A/aws/python/basic/weather/Weather_csv.ipynb#X20sZmlsZQ%3D%3D?line=0'>1</a> max_index = []
#       <a href='vscode-notebook-cell:/c%3A/aws/python/basic/weather/Weather_csv.ipynb#X20sZmlsZQ%3D%3D?line=2'>3</a> # print(seoul.iloc[0:24, 2].idxmax())
#       <a href='vscode-notebook-cell:/c%3A/aws/python/basic/weather/Weather_csv.ipynb#X20sZmlsZQ%3D%3D?line=3'>4</a>
#       <a href='vscode-notebook-cell:/c%3A/aws/python/basic/weather/Weather_csv.ipynb#X20sZmlsZQ%3D%3D?line=4'>5</a> # 서울에서 각 시간마다의 기온을 리스트에 담고 그 리스트중에 가장 큰 값의 인덱스를 리스트에 담아야함
# ----> <a href='vscode-notebook-cell:/c%3A/aws/python/basic/weather/Weather_csv.ipynb#X20sZmlsZQ%3D%3D?line=5'>6</a> print(seoul[seoul["일시"].split(" ")])
#       <a href='vscode-notebook-cell:/c%3A/aws/python/basic/weather/Weather_csv.ipynb#X20sZmlsZQ%3D%3D?line=7'>8</a> print(seoul.iloc[24:24+24, 2].idxmax())
#      <a href='vscode-notebook-cell:/c%3A/aws/python/basic/weather/Weather_csv.ipynb#X20sZmlsZQ%3D%3D?line=9'>10</a> for i in range(0, len(seoul), 24):
#
# File c:\Users\ITPS\anaconda3\Lib\site-packages\pandas\core\generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'split'
